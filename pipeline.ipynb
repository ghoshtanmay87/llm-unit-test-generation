# %%
from pipeline.full_pipeline import FullPipeline
from pipeline.pipeline_runner import run_pipeline

# %%
pipeline = FullPipeline()

# %%
mbpp_result = run_pipeline(jsonl_path="datasets/mbpp.jsonl", pipeline=pipeline, log_dir="logs", function_key="code", log_prefix="mbpp", start=885, limit=1)
# Out:
# 2025-06-13 21:08:23,140 [INFO] Logging to: logs/mbpp-20250613210823.log
# 2025-06-13 21:08:23,144 [INFO] Running Task ID: 885
# 2025-06-13 21:08:23,146 [INFO] [UserStoryGenerationAgent] processing entry function named is_Isomorphic with function code: def is_Isomorphic(str1,str2):
#     dict_str1 = {}
#     dict_str2 = {}
#     for i, value in enumerate(str1):
#         dict_str1[value] = dict_str1.get(value,[]) + [i]
#     for j, value in enumerate(str2):
#         dict_str2[value] = dict_str2.get(value,[]) + [j]
#     if sorted(dict_str1.values()) == sorted(dict_str2.values()):
#         return True
#     else:
#         return False
# 2025-06-13 21:08:39,277 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-06-13 21:08:39,281 [INFO] [UserStoryGenerationAgent] LLM Response: [
#     {
#         "scenario": "Check if two empty strings are isomorphic",
#         "input": {"str1": "", "str2": ""},
#         "expected_output": true,
# ...

# %%
mbpp_result
# Out:
# [{'task_id': 885,
#   'success': True,
#   'result': '5 tests generated',
#   'retry': 5,
#   'coverage': 100.0}]

# %%
humaneval_result = run_pipeline(jsonl_path="datasets/humaneval_cleaned.jsonl", pipeline=pipeline, log_dir="logs", function_key="function_code", log_prefix="humaneval", start=152, limit=1)
# Out:
# 2025-06-13 21:08:54,525 [INFO] Logging to: logs/humaneval-20250613210854.log
# 2025-06-13 21:08:54,526 [INFO] Running Task ID: HumanEval/151
# 2025-06-13 21:08:54,527 [INFO] [UserStoryGenerationAgent] processing entry function named double_the_difference with function code: def double_the_difference(lst):
#     return sum([i ** 2 for i in lst if i > 0 and i % 2 != 0 and ('.' not in str(i))])
# 2025-06-13 21:09:04,649 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-06-13 21:09:04,654 [INFO] [UserStoryGenerationAgent] LLM Response: [
#     {
#         "scenario": "Calculate the double the difference for a list with positive odd integers",
#         "input": {"lst": [1, 2, 3, 4, 5]},
#         "expected_output": 35.0,
#         "reasoning": "The function squares the positive odd integers in the list: 1^2 + 3^2 + 5^2 = 1 + 9 + 25 = 35."
#     },
#     {
# ...

# %%
humaneval_result
# Out:
# [{'task_id': 'HumanEval/151',
#   'success': True,
#   'result': '7 tests generated',
#   'retry': 0,
#   'coverage': 100.0}]
